# %% [markdown]
# ## import libraries

# %%
import pandas
import configparser
import psycopg2
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
config = configparser.ConfigParser()
config.read('config.ini')

host = config['myaws']['host']
db = config['myaws']['db']
user = config['myaws']['user']
pwd = config['myaws']['pwd']

# %%
conn = psycopg2.connect(host = host,
                       user = user,
                        password = pwd,
                        dbname = db
                       )
cur = conn.cursor()

# %% [markdown]
# ## create the house table

# %% [markdown]
# make sure change the schema name to your gp number

# %%
table_sql = """
            CREATE TABLE IF NOT EXISTS gp2.house
            (

                price integer,
                bed integer,
                bath integer,
                area integer,
                address VARCHAR(200),
                PRIMARY KEY(address)
            );

            """

# %% [markdown]
# use the bellow cell only if you want to delete the table

# %%
#conn.rollback()
#table_sql="drop table if exists demo.house"

# %%
cur.execute(table_sql)
conn.commit()

# %% [markdown]
# ## define the search region

# %%
url = 'https://www.trulia.com/VA/Madison/22727/'

# %%
import urllib.request
response = urllib.request.urlopen(url)
html_data= response.read()
#print(html_data.decode('utf-8'))

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_data,'html.parser')
#print (soup)

# %% [markdown]
# ## insert the records into database

# %%
for li_class in soup.find_all('li', class_ = 'Grid__CellBox-sc-144isrp-0 SearchResultsList__WideCell-b7y9ki-2 jiZmPM'):
    try:
        for price_div in li_class.find_all('div',{'data-testid':'property-price'}):
            price =int(price_div.text.replace('$','').replace(",",""))
        for bed_div in li_class.find_all('div', {'data-testid':'property-beds'}):
            bed= int(bed_div.text.replace('bd','').replace(",",""))
        for bath_div in li_class.find_all('div',{'data-testid':'property-baths'}):
            bath =int(bath_div.text.replace('ba','').replace(",",""))
        for area_div in li_class.find_all('div',{'data-testid':'property-floorSpace'}):
            area=int(area_div.text.split('sqft')[0].replace(",",""))
        for address_div in li_class.find_all('div',{'data-testid':'property-address'}):
            address =address_div.text

        try:
            sql_insert = """
                        insert into gp2.house(price,bed,bath,area,address)
                        values('{}','{}','{}','{}','{}')            
                        """.format(price,bed,bath,area,address)

            cur.execute(sql_insert)
            conn.commit()
        except:
            conn.rollback()
    except:
        pass

# %% [markdown]
# ## Query the Table

# %%
df = pandas.read_sql_query('select * from gp2.house ', conn)
df[:]
# Out:
#       price  bed  bath  area                                         address
# 0   1395000    5     5  5705          820 Hilltop Farm Ln, Madison, VA 22727
# 1    285000    3     2  1326          391 Resettlement Rd, Madison, VA 22727
# 2    279999    2     1   960           221 S White Oak Dr, Madison, VA 22727
# 3     80000    2     1   960           Laurel Lakeview Dr, Madison, VA 22727
# 4    299000    2     1   960                Pine Ridge Ln, Madison, VA 22727
# 5    350000    2     1   960                 Garth run Rd, Madison, VA 22727
# 6    489000    2     1   960                Beahm Town Rd, Madison, VA 22727
# 7    875000    3     2  1800                1103 Clore Rd, Madison, VA 22727
# 8    289777    3     2  1968          97 E Happy Hills Ln, Madison, VA 22727
# 9    335000    3     2  1968                      Duet Rd, Madison, VA 22727
# 10   209400    3     2  1968               N Seminole Trl, Madison, VA 22727
# 11    95900    3     2  1968                Innovation Ln, Madison, VA 22727
# 12   269900    3     2  1968               Bluff Mountain, Madison, VA 22727
# 13    59900    3     2  1968             Weaver Hollow Rd, Madison, VA 22727
# 14  1750000    3     2  1968              2045 Seville Rd, Madison, VA 22727
# 15   675000    3     3  4404            601 Old Forge Way, Madison, VA 22727
# 16   319000    3     2  1288            76 John Tucker Rd, Madison, VA 22727
# 17  1450000    3     2  1288         Mount Zion Church Rd, Madison, VA 22727
# 18  1750000    3     2  1288              2047 Seville Rd, Madison, VA 22727
# 19   297777    2     2  2214               1226 N Main St, Madison, VA 22727
# 20    68000    2     2  2214            Pine Torch Ln #77, Madison, VA 22727
# 21  1450000    2     2  2214            Mt zion church Rd, Madison, VA 22727
# 22    45000    3     2  1800               John Tucker Rd, Madison, VA 22727
# 23    17900    3     2  1800      Main Uno Bapt Church Ln, Madison, VA 22727
# 24   269900    3     2  1800            Bluff Mountain Rd, Madison, VA 22727
# 25    50000    3     2  1800                 Ridgeview Rd, Madison, VA 22727
# 26   595000    3     2  1800               12 Oak Park Rd, Madison, VA 22727
# 27   324500    3     2  1800                     Seminole, Madison, VA 22727
# 28   575000    3     2  1800                      Unknown, Madison, VA 22727
# 29   575000    3     2  1800         54-54-10C Seville Rd, Madison, VA 22727
# 30   389000    2     2  1987   242 Madison Mills Ln, Madison Mills, VA 22960
# 31   449900    3     3  2400          377 Logtrac Rd, Ruckersville, VA 22968
# 32   224900    3     1   864          10198 Old Rapidan Rd, Orange, VA 22960
# 33   569000    4     4  3487             8105 Tinsley Pl, Culpeper, VA 22701
# 34   275000    3     3  2380  140 Greene Acres Rd N, Stanardsville, VA 22973
# 35   245000    3     2  1470       459 W Daffodil Rd, Ruckersville, VA 22968
# 36   450000    4     4  2882          312 Sunset Dr, Stanardsville, VA 22973
# 37   299950    4     4  2088        61 E Daffodil Rd, Ruckersville, VA 22968
# 38   329900    3     2  1366            19106 Loggers Rd, Culpeper, VA 22701
# 39   272000    3     2  1392             195 Belleview Ave, Orange, VA 22960
# 40   175000    2     1   679          4654 Amicus Rd, Ruckersville, VA 22968
# 41   254900    3     2  1696         354 Logtrac Rd, Stanardsville, VA 22973
# 42   395000    2     2  1802        156 Lake View Dr, Ruckersville, VA 22968
# 43   224000    3     2  1560         3334 Weakley Hollow Rd, Syria, VA 22743
# 44   264900    3     3  1328        200 Carnation Rd, Ruckersville, VA 22968
# 45   360000    3     3  2852           671 Chapel Rd, Ruckersville, VA 22968
# 46   214900    2     1   769            1373 Park Line Rd, Stanley, VA 22851
# 47   299000    3     3  1638  693 Greene Acres Rd N, Stanardsville, VA 22973
# 48   129900    2     1   572           3702 Pine Grove Rd, Stanley, VA 22851
# 49   214500    3     1   924              224 N Madison St, Orange, VA 22960
# 50   795000    4     3  2952       9089 Liberty Mills Rd, Somerset, VA 22972
# 51   199995    3     2  1075              14357 Shanktown Rd, Reva, VA 22735
# 52   299999    3     1  1500                  132 Hidden Ln, Aroda, VA 22709
# 53   195000    2     3  2000                  553 Kirtley Rd, Leon, VA 22725
# 54   459900    4     3  2750        462 Old Mill Rd, Stanardsville, VA 22973
# 55   155000    1     1   684        115 S Circle Rd, Stanardsville, VA 22973
# 56   140000    4     2  2413           153 W Washington St, Orange, VA 22960
# 57   225000    3     1  2000          4552 Amicus Rd, Ruckersville, VA 22968
# 58   290900    3     2  1815               12134 Baylor Ln, Orange, VA 22960
# 59   564900    3     3  2368          15133 Rillhurst Dr, Culpeper, VA 22701

# %% [markdown]
# ## basic stat

# %%
df.describe()
# Out:
#               price        bed       bath         area
# count  6.000000e+01  60.000000  60.000000    60.000000
# mean   4.147900e+05   2.866667   2.100000  1840.166667
# std    3.918419e+05   0.675646   0.857667   865.958295
# min    1.790000e+04   1.000000   1.000000   572.000000
# 25%    2.148000e+05   2.750000   2.000000  1316.500000
# 50%    2.943385e+05   3.000000   2.000000  1800.000000
# 75%    4.524750e+05   3.000000   2.000000  2022.000000
# max    1.750000e+06   5.000000   5.000000  5705.000000

# %% [markdown]
# ## price distribution

# %%
df['price'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## bed vs bath

# %%
df.plot.scatter(x='bed',y='bath')
# Out:
# <AxesSubplot:xlabel='bed', ylabel='bath'>
